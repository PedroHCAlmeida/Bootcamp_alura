# %% [markdown]
# # Aula 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import ticker

# %%
@ticker.FuncFormatter
def million_formatter(x, pos):
    '''
    Formata os dados para cada Milhão e mostra duas casas decimais depois da vírgula
    '''
    return "%.2f Mi" % (x/1E6)

# %%
#dados referentes aos valores hospitalares gastos e valores hospitalares gastos corrigidos com o IPCA
dados = pd.read_csv("https://raw.githubusercontent.com/Pedro-correa-almeida/Bootcamp_alura/main/Modulo_2/dados/A084054189_28_143_208_valor_total.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    na_values='-',
                    thousands=".", decimal=",", engine="python")

# %%
dados = dados.rename(columns={'Unidade da Federação':'uf'})
dados = dados.set_index('uf')
dados.index = dados.index.str[3:]
dados = dados.drop(columns=['2008/Jan','Total'])
dados
# Out:
#                          2008/Fev      2008/Mar      2008/Abr      2008/Mai  \
# uf
# Rondônia             2.931283e+06  1.541683e+06  1.525315e+06  1.645954e+06
# Acre                 1.497206e+06  1.794028e+06  1.730469e+06  1.819444e+06
# Amazonas             7.118991e+06  8.196635e+06  8.259378e+06  7.831400e+06
# Roraima              7.779393e+05  7.186880e+05  8.399944e+05  8.623480e+05
# Pará                 1.955376e+07  2.193734e+07  2.084283e+07  2.324995e+07
# Amapá                1.268740e+06  9.746512e+05  1.141137e+06  8.663462e+05
# Tocantins            4.985689e+06  6.205613e+06  4.984482e+06  5.511002e+06
# Maranhão             1.355968e+07  1.398514e+07  1.480942e+07  1.450573e+07
# Piauí                1.007993e+07  1.029837e+07  1.077598e+07  1.039836e+07
# Ceará                2.573510e+07  2.872463e+07  3.067646e+07  3.060445e+07
# Rio Grande do Norte  9.509756e+06  1.035224e+07  1.085511e+07  1.116017e+07
# ...

# %%
mensais = dados.T
mensais
# Out:
# uf           Rondônia        Acre     Amazonas     Roraima         Pará  \
# 2008/Fev   2931283.42  1497206.26   7118990.57   777939.31  19553758.20
# 2008/Mar   1541682.52  1794028.48   8196635.49   718688.03  21937342.70
# 2008/Abr   1525314.96  1730469.42   8259378.42   839994.39  20842829.69
# 2008/Mai   1645953.84  1819443.92   7831399.90   862347.96  23249952.88
# 2008/Jun   1406150.68  1828496.00   8477273.62   832440.66  23240687.56
# ...               ...         ...          ...         ...          ...
# 2020/Nov   9357946.29  3276590.10  19895617.91  3621031.05  39004315.80
# 2020/Dez   8880836.55  3696997.31  17765167.69  3454460.94  38015145.79
# 2021/Jan   9266014.59  3715723.12  21430289.17  3266928.47  38354682.46
# 2021/Fev   7730597.04  3538427.92  25917134.55  3519773.73  37688314.23
# 2021/Mar  11023309.47  4077045.92  22032176.22  3985530.08  33276392.89
#
# uf             Amapá   Tocantins     Maranhão        Piauí        Ceará  ...  \
# ...

# %% [markdown]
# ## Desafio 01: Fazer o scatter plot feito em aula para o seu estado e Desafio 02: Formatar o eixo y colocando a escala em milhões usando o StrMethodFormatter, colocar um título e colocar o título nos 2 eixos, alterando os tamanhos dos títulos.

# %%
#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando figura e eixos
fig, ax = plt.subplots(figsize=(20,8)) 

#Criando o gráfico
sns.scatterplot(x=mensais.index, y='Rio de Janeiro', data=mensais, color='b', s=75)

#Plotando as legendas e mudando o tamanho das fontes
plt.title('Valor Gasto Pelo SUS No Rio De Janeiro', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12, rotation=30)
plt.ylim(0, 125000000)
ax.yaxis.set_major_formatter(million_formatter)
ax.xaxis.set_major_locator(ticker.IndexLocator(6,5))

#Mostrando o gráfico
plt.show()

# %% [markdown]
# A partir do scatter plot percebe se que os gastos no Rio de Janeiro vem numa constante crescente, o que faz sentido até por causa da inflação ao longo do tempo que não está sendo levado em conta.

# %% [markdown]
# ## Desafio 02: Formatar o eixo y colocando a escala em milhões usando o StrMethodFormatter, colocar um título e colocar o título nos 2 eixos, alterando os tamanhos dos títulos.

# %%
#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando figura e eixos
fig, ax = plt.subplots(figsize=(20,8)) 

#Criando o gráfico
sns.lineplot(x=mensais.index, y='Rio de Janeiro', data=mensais, color='b')

#Plotando as legendas e mudando o tamanho das fontes
plt.title('Valor Gasto Pelo SUS No Rio De Janeiro', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12, rotation=30)
plt.ylim(0, 125000000)
ax.yaxis.set_major_formatter(million_formatter)
ax.xaxis.set_major_locator(ticker.IndexLocator(6,5))

#Mostrando o gráfico
plt.show()

# %% [markdown]
# Agora com um gráfico de linha podemos ter a mesma percepção dessa crescente ao longo do tempo.

# %%
mensais.to_csv('C:/Users/pedro/Documents/Bootcamp_alura/Modulo_2/dados/dados_aula3')
