# %% [markdown]
# # Aula 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dados = pd.read_csv("C:/Users/pedro/Documents/Bootcamp_alura/Modulo_1/dados/A083728189_28_143_208_atendimento.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",", engine="python")

# %%
pd.options.display.float_format = "{:.2f}".format
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2020/Jul    2020/Ago    2020/Set  \
# 0        -        -        -  ... 10479989.36 11433467.56  8876900.39
# 1        -        -        -  ...  4053085.41  3658265.59  3470409.45
# 2        -        -        -  ... 19303743.16 18687233.58 18628627.49
# 3        -        -        -  ...  3192075.41  3262354.34  2978629.22
# 4        -        -        -  ... 40496349.97 38793393.54 36965951.76
#
#      2020/Out    2020/Nov    2020/Dez    2021/Jan    2021/Fev    2021/Mar  \
# ...

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando o gráfico 
sns.barplot(x='Unidade da Federação', y='2008/Ago', data=dados.sort_values('2008/Ago'), palette='Oranges', ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Em Agosto De 2008 Por UF', fontsize=20)
plt.xlabel('Unidade Federativa', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks( fontsize=12, rotation=90)
plt.yticks(fontsize=12)
    
#Mostrando o gráfico
plt.show()

# %%
col_preenchidas = dados.mean().index
col_preenchidas = col_preenchidas.insert(0, 'Unidade da Federação')
filtrados = dados[col_preenchidas]
filtrados.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Jul  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ... 10479989.36
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  4053085.41
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 19303743.16
# 3   808448.39   771687.83   876091.18   896952.53  ...  3192075.41
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 40496349.97
#
#      2020/Ago    2020/Set    2020/Out    2020/Nov    2020/Dez    2021/Jan  \
# ...

# %%
filtrados.set_index('Unidade da Federação', inplace=True)

# %%
filtrados.drop('Total', axis=1, inplace=True)
filtrados.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# ## Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando o gráfico 
filtrados.T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre 2007 E 2021 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# ## Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
Estados_escolhidos = ['33 Rio de Janeiro', '35 São Paulo', '29 Bahia', '15 Pará', '42 Santa Catarina']

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando o gráfico 
filtrados.loc[Estados_escolhidos].T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre 2007 E 2021 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# # Aula 3

# %% [markdown]
# ## Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#criando uma palheta de 27 cores
sns.set_palette(sns.color_palette("gist_rainbow", 27))

#Criando o gráfico 
filtrados.T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre 2007 E 2021 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# ## Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
col_regiao=[]
regioes=['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste']

for row in filtrados.iterrows():
    
    estado=row[0]
    num_reg = int(estado.split(' ')[0])
    new_estado = estado.split(' ', maxsplit =1)[1]
    filtrados = filtrados.rename(index={estado:new_estado})
    
    if num_reg < 20:
        col_regiao.append(regioes[0])
    elif num_reg < 30:
        col_regiao.append(regioes[1])
    elif num_reg < 40:
        col_regiao.append(regioes[2])
    elif num_reg < 50:
        col_regiao.append(regioes[3])
    else:
        col_regiao.append(regioes[4])

# %%
filtrados['regiao']=col_regiao
filtrados.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# Rondônia               4209.37  16397.03  133645.19  346912.84   711758.31
# Acre                  10470.07  14001.71   86200.85  301323.68   769612.36
# Amazonas              35752.72  45570.64  416012.30 2020381.79  5949408.99
# Roraima                4785.91  11858.63   43852.67  369328.51   470676.43
# Pará                 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# Rondônia              1829559.71  1940792.63  1955721.68  2143353.81
# Acre                  1731744.62  1743978.66  2057439.02  2057829.69
# Amazonas             11419210.08  7934652.10  8641517.13  8531576.49
# Roraima                808448.39   771687.83   876091.18   896952.53
# Pará                 21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
filtrados['Total'] = filtrados.sum(axis=1)
filtrados.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# Rondônia               4209.37  16397.03  133645.19  346912.84   711758.31
# Acre                  10470.07  14001.71   86200.85  301323.68   769612.36
# Amazonas              35752.72  45570.64  416012.30 2020381.79  5949408.99
# Roraima                4785.91  11858.63   43852.67  369328.51   470676.43
# Pará                 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# Rondônia              1829559.71  1940792.63  1955721.68  2143353.81
# Acre                  1731744.62  1743978.66  2057439.02  2057829.69
# Amazonas             11419210.08  7934652.10  8641517.13  8531576.49
# Roraima                808448.39   771687.83   876091.18   896952.53
# Pará                 21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenado = filtrados.sort_values('Total', ascending=False).drop('Total', axis=1)

# %%
ordenado.iloc[:,:-1].sum().sort_values(ascending=False)
# Out:
# 2008/Jan   2061263915.87
# 2020/Jul   1557715742.07
# 2020/Ago   1517383645.93
# 2020/Out   1455575204.34
# 2020/Set   1455543824.67
#                 ...
# 2007/Dez    333103304.40
# 2007/Nov    148968559.33
# 2007/Out     65884400.02
# 2007/Set     21279921.98
# 2007/Ago      8233724.90
# Length: 164, dtype: float64

# %%
ordenado.iloc[:, 5:18].sum()
# Out:
# 2008/Jan   2061263915.87
# 2008/Fev    643175383.95
# 2008/Mar    698752215.12
# 2008/Abr    707751731.60
# 2008/Mai    707899196.86
# 2008/Jun    707963348.89
# 2008/Jul    742234273.66
# 2008/Ago    719316857.74
# 2008/Set    730439883.57
# 2008/Out    758364974.45
# 2008/Nov    738631334.59
# 2008/Dez    723283658.91
# 2009/Jan    824393434.15
# dtype: float64

# %% [markdown]
# Percebe se que Janeiro de 2008 é o mês com maior gasto de todos, porém esta muito discrepante principalmente se comparados a outros meses da época, podendo indicar algum problema nos dados.

# %% [markdown]
# ## Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#criando uma palheta de 27 cores
sns.set_palette(sns.color_palette("Set1", 5))

#Criando o gráfico 
ordenado.drop('regiao', axis=1).head(5).T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre 2007 E 2021 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# ### Eliminar colunas antes de fev/2008

# %%
ordenado = ordenado.iloc[:,6:]
ordenado.head()
# Out:
#                          2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# São Paulo            172961999.58 170556696.16 170338163.23 172462057.87
# Minas Gerais          70301089.50  79119005.51  79046322.41  79268070.12
# Paraná                48855046.46  55611791.07  56115135.82  55574831.93
# Rio Grande do Sul     45897704.82  52928695.92  51972416.77  51679350.79
# Rio de Janeiro        44128159.73  42900847.02  45306499.53  43951349.46
#
#                          2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# São Paulo            175492995.85 179569910.06 180005050.15 180151656.17
# Minas Gerais          79619189.20  82209206.98  80374117.08  82409129.30
# Paraná                56094754.74  59802402.07  56699001.13  58091985.79
# Rio Grande do Sul     53759674.01  56391647.77  56233758.74  57910170.98
# Rio de Janeiro        44111107.27  44359056.71  42500830.29  43066461.47
#
# ...

# %% [markdown]
# ## Desafio 04: Adicione um estado a escolha no gráfico

# %%
estados = ordenado.head(5).index.to_list()
estados.append('Bahia')
estados
# Out:
# ['São Paulo',
#  'Minas Gerais',
#  'Paraná',
#  'Rio Grande do Sul',
#  'Rio de Janeiro',
#  'Bahia']

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#criando uma palheta de 27 cores
sns.set_palette(sns.color_palette("Set1", 6))

#Criando o gráfico 
ordenado.drop('regiao', axis=1).loc[estados].T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre Fev De 2008 E Mar De 2021 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# ## Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue

# %%
from IPython.display import Image
filename = 'C:/Users/pedro/Documents/Bootcamp_alura/Modulo_1/dados/dengue-no-brasil.jpg'
Image(filename = filename, width=1000, height=1000)

# %% [markdown]
# Observando o gráfico de casos de dengue no brasil percebemos que o ano de 2013 e 2015 foram os anos com maiores surtos entre 1990 e 2015, ou seja um aumento dos gastos públicos destinados a saúde nesse anos podem ser esperados

# %% [markdown]
# fonte : https://agenciapatriciagalvao.org.br/mulheres-de-olho/dsr/eua-alertam-gestantes-para-evitar-ida-ao-brasil-e-paises-expostos-ao-zika/attachment/dengue-no-brasil/

# %% [markdown]
# ## Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região

# %%
ordenado.loc['Rio de Janeiro'].drop('regiao').sort_values(ascending=False)
# Out:
# 2013/Jan   102104204.33
# 2020/Jul    95941141.03
# 2020/Dez    90567351.87
# 2020/Ago    89795469.41
# 2020/Mai    89725279.21
#                ...
# 2008/Dez    43024756.36
# 2008/Mar    42900847.02
# 2008/Ago    42500830.29
# 2008/Nov    41351511.51
# 2009/Fev    40668378.23
# Name: Rio de Janeiro, Length: 158, dtype: object

# %% [markdown]
# Observando os dados vemos que o pico de gastos no Rio de Janeiro foi em Janeiro de 2013

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#criando uma palheta de 27 cores
sns.set_palette(sns.color_palette("Set1", 6))

#Criando o gráfico 
ordenado.drop('regiao', axis=1).loc[ordenado['regiao']=='Sudeste'].T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre Fev De 2008 E Jul De 2020 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')

#Mostrando o gráfico
plt.show()

# %% [markdown]
# Observando o gráfico com apenas informações sobre a região sudeste percebe-se que em 2013 os estados mais afetados foram Rio de Janeiro e São Paulo, porém os demais não tiveram aumentos significativos nessa época

# %%
from IPython.display import Image
filename = 'C:/Users/pedro/Documents/Bootcamp_alura/Modulo_1/dados/dengue2013.png'
Image(filename = filename, width=200, height=200)

# %% [markdown]
# fonte: http://g1.globo.com/bemestar/noticia/2013/02/casos-de-dengue-no-pais-aumentam-190-no-comeco-de-2013-diz-governo.html

# %% [markdown]
# A partir da pesquisa sobre a dengue no brasil nesse ano de 2013, mais especificamente em Janeiro, foi achado que o Rio de Janeiro não foi o estado mais afetado com a dengue no começo de 2013, na verdade ele teve uma redução em relação ao mesmo período de 2012, ou seja aquele pico em Janeiro de 2013 tem outro motivo

# %% [markdown]
# ## Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo

# %%
lista=[]
for data in ordenado.drop('regiao', axis=1).columns:
    mes = data[-3:]
    if mes=='Jan' or mes=='Jul':
        lista.append(data)
    else:
        lista.append('')

# %%
len(lista)
# Out:
# 158

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando uma palheta de 6 cores
sns.set_palette(sns.color_palette('Set1', 6))

#Criando o gráfico 
ordenado.drop('regiao', axis=1).loc[estados].T.plot(ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público De Atendimentos Entre Fev De 2008 E Jul De 2020 Por UF', fontsize=20)
plt.xlabel('Ano/Mês', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.yticks(fontsize=12)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(range(len(lista)), lista, fontsize=12, rotation=90)

#Mostrando o gráfico
plt.show()

# %% [markdown]
# Agora com o gráfico mostrando janeiro e julho de cada ano podemos ver melhor que o pico de gasto no Rio de Janeiro foi em janeiro de 2013, conseguimos com o gráfico ver a discrepância que há nos gastos de São Paulo em relação aos outros estados, com certeza pelo fato de ser um estado grande e muito populoso.

# %% [markdown]
# Outra informação que podemos tirar observando o gráfico é que o Rio de Janeiro e São Paulo aparentam ter uma maior variação de valores durante o tempo do que os outros estados.
