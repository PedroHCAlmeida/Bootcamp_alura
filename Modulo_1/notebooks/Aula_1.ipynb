# %% [markdown]
# # Aula 1

# %%
import pandas as pd

dados = pd.read_csv("C:/Users/pedro/Documents/Bootcamp_alura/Modulo_1/dados/A151346189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",", engine="python")

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2019/Dez     2020/Jan     2020/Fev     2020/Mar     2020/Abr  \
# ...

# %%
pd.options.display.float_format = "{:.2f}".format
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %% [markdown]
# ## Visualização

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando o gráfico 
sns.barplot(x='Unidade da Federação', y='2008/Ago', data=dados.sort_values('2008/Ago'), palette='Oranges', ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público Processado Em Agosto De 2008 Por UF', fontsize=20)
plt.xlabel('Unidade', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks( fontsize=12, rotation=90)
plt.yticks(fontsize=12)
    
#Mostrando o gráfico
plt.show()

# %%
import numpy as np

# %%
dados['2020/Ago'].dtype
# Out:
# dtype('O')

# %%
dados['2020/Ago'].unique()
# Out:
# array(['10285455.78', '-', '14726443.67', '2826486.18', '39911193.02',
#        '2942273.94', '8240261.38', '28587541.78', '23210624.20',
#        '59808605.59', '24929930.72', '22130016.81', '75704177.72',
#        '19754741.78', '11014180.89', '80793117.08', '168024412.95',
#        '32188873.88', '95274486.35', '346512263.17', '129375911.54',
#        '63972379.36', '101374341.51', '19241624.02', '17790649.87',
#        '43984702.05', '26526196.39'], dtype=object)

# %%
dados['2020/Ago'].replace('-', np.nan, inplace=True)

# %%
dados['2020/Ago'] = dados['2020/Ago'].astype('float64').dropna()

# %%
#Criando figura e eixos
fig, ax = plt.subplots(figsize=(12,8)) 

#Mudando o estilo de fundo
sns.set_style('darkgrid')

#Criando o gráfico 
sns.barplot(x='Unidade da Federação', y='2020/Ago', data=dados.sort_values('2020/Ago').dropna(), palette='Oranges', ax=ax)

#Plotando as legendas e mudando o tamanho das fontes
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Gasto Hospitalar Público Processado Em Agosto De 2020 Por UF', fontsize=20)
plt.xlabel('Unidade Federativa', fontsize=15)
plt.ylabel('Valor Total', fontsize=15)
plt.xticks( fontsize=12, rotation=90)
plt.yticks(fontsize=12)
    
#Mostrando o gráfico
plt.show()
